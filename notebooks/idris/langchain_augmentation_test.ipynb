# %%
import os
import pandas as pd
from langchain_community.utilities import SQLDatabase
from gait.idris import Idris, IdrisTrainer, IdrisLiteEmb, IdrisLiteLLM, IdrisRDB
import pyspark
from typing import List
import litellm


# optional – shows the exact URL LiteLLM calls, very useful for debugging
litellm._turn_on_debug()       

# 1. Create a small test DataFrame
data = {
    'id': [1, 2, 3, 4, 5],
    'name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'age': [25, 30, 35, 40, 45],
    'department': ['HR', 'Engineering', 'Sales', 'Marketing', 'Engineering']
}
df = pd.DataFrame(data)

# 2. Set up a SQLite database for LangChain
import sqlite3
conn = sqlite3.connect('test.db')
df.to_sql('employees', conn, if_exists='replace', index=False)
db = SQLDatabase.from_uri("sqlite:///test.db")

# 3. Create trainer and generate initial pairs
trainer = IdrisTrainer()
result = trainer.train(df, "employees", limit=5)

# 4. Print initial pairs
print(f"Initial pairs count: {len(result.question_sql)}")
print("\nSample pairs:")
for nl, sql in result.question_sql[:3]:
    print(f"NL: {nl}")
    print(f"SQL: {sql}")
    print("---")

# 5. Augment with LangChain (set your OpenAI API key)
import os
from dotenv import load_dotenv
#load_dotenv()  # This will load the .env file from the project root
#os.environ["OPENAI_API_KEY"] = "4e86557a89d24a95a61d41e02cf62d1d"
env_path = r"C:\Users\jac10179\Documents\Admin\Career\2025\AI\Fork\gait-main-JE\.env"
load_dotenv(dotenv_path=env_path)

# Update your notebook test to not specify a model (use env settings)
aug_pairs = trainer.augment_pairs_with_langchain(
    result.question_sql[:3],
    db,
    model_name=None,  # This will use AZURE_OPENAI_DEPLOYMENT from env
    paraphrases_per_query=2
)

# 6. Print augmented pairs
print(f"\nAugmented pairs count: {len(aug_pairs)}")
print("\nSample augmented pairs:")
for nl, sql in aug_pairs[:3]:
    print(f"NL: {nl}")
    print(f"SQL: {sql}")
    print("---")

# 7. Try the combined training method
combined_result = trainer.train_with_langchain_augmentation(
    df, 
    "employees", 
    db,
    limit=3,
    model_name=None,  # Use env settings
    paraphrases_per_query=1
)

print(f"\nCombined training pairs count: {len(combined_result.question_sql)}")

#Create a mock RDB class
class MockRDB(IdrisRDB):
    @property
    def dialect(self) -> str:
        return "SQLite"  # or whatever dialect you want to mock
    
    def _get_create_table_columns(self, table_name: str) -> List[str]:
        # Return a mock list of columns
        return ["id INTEGER", "name VARCHAR", "age INTEGER", "department VARCHAR"]
    
    def execute_sql(self, sql: str) -> pd.DataFrame:
        print(f"Would execute: {sql}")
        # Return an empty DataFrame with the expected columns
        return pd.DataFrame(columns=["id", "name", "age", "department"])


# 8. Test with Idris instance
rdb = MockRDB()

# Use environment variables for embedding model
llm = IdrisLiteLLM(
    model_name=os.getenv("AZURE_API_DEPLOYMENT"),  # "gpt-4o"
    api_base=os.getenv("AZURE_API_BASE"),
    api_key=os.getenv("AZURE_API_KEY"),
    api_version=os.getenv("AZURE_API_VERSION")
)

# Use text-embedding-3-large for embeddings

emb = IdrisLiteEmb(
    model_name="azure/text-embedding-ada-002",
    api_base="https://ist-apim-aoai.azure-api.net/load-balancing/text-embedding-ada-002",
    api_version="2024-10-21",
    api_key="4e86557a89d24a95a61d41e02cf62d1d",
)

idris = Idris(rdb, emb, llm)
idris.add_create_table(combined_result.create_table)
idris.load_context(combined_result.context)
idris.load_question_sql(combined_result.question_sql)

# 9. Test query
sql = idris.generate_sql("Who works in Engineering?")
print(f"\nGenerated SQL: {sql}")

# 10. Test direct augmentation of an Idris instance
idris.augment_question_sql_with_langchain(
    db,
    paraphrases_per_query=1
)
print(f"\nFinal pairs count: {len(idris.dump_question_sql())}")

# After generating the pairs (either initial or augmented), add this code:

import json
from datetime import datetime

# Create a dictionary with metadata and the pairs
output_data = {
    "timestamp": datetime.now().isoformat(),
    "pairs": [
        {
            "natural_language": nl,
            "sql": sql
        }
        for nl, sql in result.question_sql  # or aug_pairs if you want to save augmented pairs
    ]
}

# Save to a JSON file with timestamp in the name
output_filename = f"sql_nl_pairs_{datetime.now().strftime('%Y%m%d_%H%M%S')}.json"
with open(output_filename, 'w') as f:
    json.dump(output_data, f, indent=2)

print(f"Saved {len(output_data['pairs'])} pairs to {output_filename}")
# Out:
# Initial pairs count: 19
#
# Sample pairs:
# NL: Show employees where id is greater than 4
# SQL: SELECT * FROM employees where id>'4'
# ---
# NL: Show employees where id is less than 2
# SQL: SELECT * FROM employees where id<'2'
# ---
# NL: Show employees where id is less than 3
# SQL: SELECT * FROM employees where id<'3'
# ---
#
# Augmented pairs count: 6
#
# Sample augmented pairs:
# NL: Show employees where id is greater than 4
# SQL: SELECT "id", "name", "age", "department" FROM "employees" WHERE "id" > 4 LIMIT 5;
# ---
# NL: Show employees where id is greater than 4
# SQL: SELECT "id", "name", "age", "department" FROM employees WHERE "id" > 4 LIMIT 5;
# ---
# NL: Show employees where id is less than 2
# SQL: SELECT "id", "name", "age", "department"
# FROM employees
# WHERE "id" < 2
# LIMIT 5;
# ---
# 23:12:37 - LiteLLM:DEBUG: utils.py:331 -
#
# 23:12:37 - LiteLLM:DEBUG: utils.py:331 - Request to litellm:
# 23:12:37 - LiteLLM:DEBUG: utils.py:331 - litellm.embedding(input=["Use column 'id' in reference to id.", "Use column 'name' in reference to name.", "Use column 'age' in reference to age.", "Use column 'department' in reference to department."], model='azure/text-embedding-ada-002', api_base='https://ist-apim-aoai.azure-api.net/load-balancing/text-embedding-ada-002', api_version='2024-10-21', api_key='4e86557a89d24a95a61d41e02cf62d1d')
# 23:12:37 - LiteLLM:DEBUG: utils.py:331 -
#
# 23:12:37 - LiteLLM:DEBUG: litellm_logging.py:427 - self.optional_params: {}
# 23:12:37 - LiteLLM:DEBUG: utils.py:331 - SYNC kwargs[caching]: False; litellm.cache: None; kwargs.get('cache')['no-cache']: False
# 23:12:37 - LiteLLM:DEBUG: litellm_logging.py:427 - self.optional_params: {}
# 23:12:37 - LiteLLM:DEBUG: litellm_logging.py:870 - {'litellm_trace_id': None, 'litellm_call_id': 'd3508da4-d6dd-4724-99a2-ffeb2388d06a', 'input': ["Use column 'id' in reference to id.", "Use column 'name' in reference to name.", "Use column 'age' in reference to age.", "Use column 'department' in reference to department."], 'litellm_params': {'acompletion': None, 'api_key': None, 'force_timeout': 600, 'logger_fn': None, 'verbose': False, 'custom_llm_provider': None, 'api_base': '', 'litellm_call_id': None, 'model_alias_map': None, 'completion_call_id': None, 'aembedding': None, 'metadata': None, 'model_info': None, 'proxy_server_request': None, 'preset_cache_key': None, 'no-log': None, 'stream_response': {}, 'input_cost_per_token': None, 'input_cost_per_second': None, 'output_cost_per_token': None, 'output_cost_per_second': None, 'cooldown_time': None, 'text_completion': None, 'azure_ad_token_provider': None, 'user_continue_message': None, 'base_model': None, 'litellm_trace_id': None, 'litellm_session_id': None, 'hf_model_name': None, 'custom_prompt_dict': None, 'litellm_metadata': None, 'disable_add_transform_inline_image_block': None, 'drop_params': None, 'prompt_id': None, 'prompt_variables': None, 'async_call': None, 'ssl_verify': None, 'merge_reasoning_content_in_choices': None, 'api_version': None, 'azure_ad_token': None, 'tenant_id': None, 'client_id': None, 'client_secret': None, 'azure_username': None, 'azure_password': None, 'max_retries': None, 'timeout': None, 'bucket_name': None, 'vertex_credentials': None, 'vertex_project': None}, 'applied_guardrails': [], 'model': 'text-embedding-ada-002', 'messages': [{'role': 'user', 'content': "Use column 'id' in reference to id."}, {'role': 'user', 'content': "Use column 'name' in reference to name."}, {'role': 'user', 'content': "Use column 'age' in reference to age."}, {'role': 'user', 'content': "Use column 'department' in reference to department."}], 'optional_params': {}, 'start_time': datetime.datetime(2025, 5, 9, 23, 12, 37, 770293), 'stream': False, 'user': None, 'call_type': 'embedding', 'completion_start_time': None, 'standard_callback_dynamic_params': {}, 'stream_options': None, 'custom_llm_provider': 'azure', 'api_key': '4e86557a89d24a95a61d41e02cf62d1d', 'additional_args': {'complete_input_dict': {'model': 'text-embedding-ada-002', 'input': ["Use column 'id' in reference to id.", "Use column 'name' in reference to name.", "Use column 'age' in reference to age.", "Use column 'department' in reference to department."]}, 'headers': {'api_key': '4e86557a89d24a95a61d41e02cf62d1d', 'azure_ad_token': None}}, 'log_event_type': 'pre_api_call'}
# Combined training pairs count: 24
# 23:12:37 - LiteLLM:DEBUG: common_utils.py:384 - Initializing Azure OpenAI Client for text-embedding-ada-002, Api Base: https://ist-apim-aoai.azure-api.net/load-balancing/text-embedding-ada-002, Api Key:4e86557a***************
# 23:12:39 - LiteLLM:DEBUG: utils.py:331 - RAW RESPONSE:
# CreateEmbeddingResponse(data=[Embedding(embedding=[-0.011497343890368938, 0.011531440541148186, -0.0040643042884767056, 0.0040199789218604565, -0.010788137093186378, 0.005145163740962744, -0.017893850803375244, -0.010604015551507473, 0.0032221204601228237, -0.010849510319530964, 0.027004437521100044, -0.00840819999575615, 0.02280374802649021, 0.0015880450373515487, -0.022926494479179382, 0.0045962100848555565, 0.030168594792485237, -0.00657039787620306, 0.011285945773124695, -0.018930383026599884, -0.022408228367567062, 0.01642088033258915, 0.0065533495508134365, -0.01102681178599596, -0.016966424882411957, 0.020717041566967964, 0.03295087069272995, -0.030959634110331535, -0.008660513907670975, -0.00448710098862648, 0.004043846391141415, -0.016025360673666, 0.003488073358312249, -0.03180522844195366, -0.0420614592730999, 0.00394155690446496, -0.0003158189356327057, -0.008360465057194233, 0.03426017612218857, 0.006638591177761555, 0.03311453387141228, -0.013058964163064957, -0.004988319706171751, -0.011510983109474182, 0.012186093255877495, 0.0182211771607399, 0.0034164704848080873, -0.00935608334839344, -0.010822232812643051, -0.0052372245118021965, -0.005919154733419418, 0.042634278535842896, -0.04028844088315964, -0.0014525114092975855, -0.0032374639995396137, -0.005138344597071409, 0.0001434184523532167, 0.014716055244207382, -0.0055918279103934765, -0.003617639886215329, -0.0002435769565636292, 0.007003423757851124, -0.0049337656237185, -8.593386883148924e-05, -0.022135455161333084, -0.00012700950901489705, 0.0070647974498569965, -0.007889932952821255, 0.005646382458508015, 0.017348306253552437, 0.01950320601463318, 0.024454018101096153, 0.00936972163617611, 0.010610834695398808, -0.011524621397256851, -0.00884463544934988, -0.005530454218387604, 0.0011507573071867228, 0.021317139267921448, -0.019189517945051193, 0.0011089891195297241, -0.012377033941447735, -0.0255314689129591, 0.007780824322253466, 0.03207799792289734, 0.028695624321699142, 0.022012708708643913, 0.01707553304731846, 0.0075626065954566, -0.00043068156810477376, 0.007842198014259338, 0.024031221866607666, 0.0003151796408928931, -0.009553843177855015, 0.01642088033258915, 0.029159337282180786, 0.00157014443539083, 0.025313250720500946, 0.012247467413544655, -0.004753053653985262, 0.0014354632003232837, 0.012029250152409077, -0.02040335349738598, -0.003041408956050873, -0.027904586866497993, 0.010283508338034153, 0.015534371137619019, -0.016216302290558815, 0.011926960200071335, -0.002968101529404521, -0.012424768880009651, 0.03322364017367363, 0.030468644574284554, -0.015370707958936691, 0.00840819999575615, -0.008660513907670975, -0.004023388493806124, -0.023662980645895004, -0.014716055244207382, 0.017239196226000786, 0.01468877773731947, 0.013809087686240673, -0.006270348560065031, -0.02669074945151806, 0.02487681619822979, -0.008230898529291153, -0.021467164158821106, -0.008374103344976902, 0.013195350766181946, -0.01947592757642269, 0.03641507402062416, 0.02820463478565216, 0.001634075422771275, 0.002584515605121851, -0.006645410321652889, 0.005117886699736118, -0.02306288108229637, 0.008224078454077244, -0.01910768635571003, -0.051226601004600525, 0.028150081634521484, 0.010344881564378738, 0.0001799656602088362, -0.0016178794903680682, 0.029541218653321266, 0.005308826919645071, 0.005370200611650944, 0.013379471376538277, -0.014334173873066902, -0.012670264579355717, -0.0023577739484608173, -0.004824656527489424, 0.010283508338034153, -0.0024293765891343355, 0.01410231739282608, 0.01704825647175312, -0.026363423094153404, 0.006444240920245647, 0.004899668972939253, -0.012854385189712048, -0.007664896082133055, 0.04053393378853798, 0.0021003452129662037, -0.015957167372107506, 0.030086763203144073, 0.026445254683494568, 0.014170510694384575, 0.018916744738817215, -0.025804240256547928, 0.015848059207201004, 0.024958647787570953, 0.012145177461206913, -0.012697541154921055, 0.0028470586985349655, 0.006273758132010698, 0.01640724204480648, 0.01778474077 ...
#
#
# 23:12:39 - LiteLLM:INFO: utils.py:1184 - Wrapper: Completed Call, calling success_handler
# 23:12:39 - LiteLLM:DEBUG: litellm_logging.py:1315 - Logging Details LiteLLM-Success Call: Cache_hit=None
# 23:12:39 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: azure/text-embedding-ada-002
# 23:12:39 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: azure/text-embedding-ada-002
# 23:12:39 - LiteLLM:DEBUG: utils.py:4154 - checking potential_model_names in litellm.model_cost: {'split_model': 'text-embedding-ada-002', 'combined_model_name': 'azure/text-embedding-ada-002', 'stripped_model_name': 'text-embedding-ada-002', 'combined_stripped_model_name': 'azure/text-embedding-ada-002', 'custom_llm_provider': 'azure'}
# 23:12:39 - LiteLLM:DEBUG: utils.py:4154 - checking potential_model_names in litellm.model_cost: {'split_model': 'text-embedding-ada-002', 'combined_model_name': 'azure/text-embedding-ada-002', 'stripped_model_name': 'text-embedding-ada-002', 'combined_stripped_model_name': 'azure/text-embedding-ada-002', 'custom_llm_provider': 'azure'}
# 23:12:39 - LiteLLM:DEBUG: utils.py:4450 - model_info: {'key': 'azure/text-embedding-ada-002', 'max_tokens': 8191, 'max_input_tokens': 8191, 'max_output_tokens': None, 'input_cost_per_token': 1e-07, 'cache_creation_input_token_cost': None, 'cache_read_input_token_cost': None, 'input_cost_per_character': None, 'input_cost_per_token_above_128k_tokens': None, 'input_cost_per_token_above_200k_tokens': None, 'input_cost_per_query': None, 'input_cost_per_second': None, 'input_cost_per_audio_token': None, 'input_cost_per_token_batches': None, 'output_cost_per_token_batches': None, 'output_cost_per_token': 0.0, 'output_cost_per_audio_token': None, 'output_cost_per_character': None, 'output_cost_per_reasoning_token': None, 'output_cost_per_token_above_128k_tokens': None, 'output_cost_per_character_above_128k_tokens': None, 'output_cost_per_token_above_200k_tokens': None, 'output_cost_per_second': None, 'output_cost_per_image': None, 'output_vector_size': None, 'litellm_provider': 'azure', 'mode': 'embedding', 'supports_system_messages': None, 'supports_response_schema': None, 'supports_vision': False, 'supports_function_calling': False, 'supports_tool_choice': False, 'supports_assistant_prefill': False, 'supports_prompt_caching': False, 'supports_audio_input': False, 'supports_audio_output': False, 'supports_pdf_input': False, 'supports_embedding_image_input': False, 'supports_native_streaming': None, 'supports_web_search': False, 'supports_reasoning': False, 'search_context_cost_per_query': None, 'tpm': None, 'rpm': None}
# 23:12:39 - LiteLLM:DEBUG: utils.py:4450 - model_info: {'key': 'azure/text-embedding-ada-002', 'max_tokens': 8191, 'max_input_tokens': 8191, 'max_output_tokens': None, 'input_cost_per_token': 1e-07, 'cache_creation_input_token_cost': None, 'cache_read_input_token_cost': None, 'input_cost_per_character': None, 'input_cost_per_token_above_128k_tokens': None, 'input_cost_per_token_above_200k_tokens': None, 'input_cost_per_query': None, 'input_cost_per_second': None, 'input_cost_per_audio_token': None, 'input_cost_per_token_batches': None, 'output_cost_per_token_batches': None, 'output_cost_per_token': 0.0, 'output_cost_per_audio_token': None, 'output_cost_per_character': None, 'output_cost_per_reasoning_token': None, 'output_cost_per_token_above_128k_tokens': None, 'output_cost_per_character_above_128k_tokens': None, 'output_cost_per_token_above_200k_tokens': None, 'output_cost_per_second': None, 'output_cost_per_image': None, 'output_vector_size': None, 'litellm_provider': 'azure', 'mode': 'embedding', 'supports_system_messages': None, 'supports_response_schema': None, 'supports_vision': False, 'supports_function_calling': False, 'supports_tool_choice': False, 'supports_assistant_prefill': False, 'supports_prompt_caching': False, 'supports_audio_input': False, 'supports_audio_output': False, 'supports_pdf_input': False, 'supports_embedding_image_input': False, 'supports_native_streaming': None, 'supports_web_search': False, 'supports_reasoning': False, 'search_context_cost_per_query': None, 'tpm': None, 'rpm': None}
# 23:12:39 - LiteLLM:DEBUG: litellm_logging.py:1093 - response_cost: 4e-06
# 23:12:39 - LiteLLM:DEBUG: litellm_logging.py:1093 - response_cost: 4e-06
# 23:12:39 - LiteLLM:DEBUG: utils.py:331 -
#
# 23:12:39 - LiteLLM:DEBUG: utils.py:4154 - checking potential_model_names in litellm.model_cost: {'split_model': 'text-embedding-ada-002', 'combined_model_name': 'azure/text-embedding-ada-002', 'stripped_model_name': 'text-embedding-ada-002', 'combined_stripped_model_name': 'azure/text-embedding-ada-002', 'custom_llm_provider': 'azure'}
# 23:12:39 - LiteLLM:DEBUG: utils.py:331 - Request to litellm:
# 23:12:39 - LiteLLM:DEBUG: utils.py:4450 - model_info: {'key': 'azure/text-embedding-ada-002', 'max_tokens': 8191, 'max_input_tokens': 8191, 'max_output_tokens': None, 'input_cost_per_token': 1e-07, 'cache_creation_input_token_cost': None, 'cache_read_input_token_cost': None, 'input_cost_per_character': None, 'input_cost_per_token_above_128k_tokens': None, 'input_cost_per_token_above_200k_tokens': None, 'input_cost_per_query': None, 'input_cost_per_second': None, 'input_cost_per_audio_token': None, 'input_cost_per_token_batches': None, 'output_cost_per_token_batches': None, 'output_cost_per_token': 0.0, 'output_cost_per_audio_token': None, 'output_cost_per_character': None, 'output_cost_per_reasoning_token': None, 'output_cost_per_token_above_128k_tokens': None, 'output_cost_per_character_above_128k_tokens': None, 'output_cost_per_token_above_200k_tokens': None, 'output_cost_per_second': None, 'output_cost_per_image': None, 'output_vector_size': None, 'litellm_provider': 'azure', 'mode': 'embedding', 'supports_system_messages': None, 'supports_response_schema': None, 'supports_vision': False, 'supports_function_calling': False, 'supports_tool_choice': False, 'supports_assistant_prefill': False, 'supports_prompt_caching': False, 'supports_audio_input': False, 'supports_audio_output': False, 'supports_pdf_input': False, 'supports_embedding_image_input': False, 'supports_native_streaming': None, 'supports_web_search': False, 'supports_reasoning': False, 'search_context_cost_per_query': None, 'tpm': None, 'rpm': None}
# 23:12:39 - LiteLLM:DEBUG: utils.py:331 - litellm.embedding(input=['Show employees where id is 1', 'Show employees where id is less than 2', 'Show employees where id is greater than 3', 'Show employees where name is not eve', 'Show employees where name is david', 'Show employees where name is alice', 'Show employees where age is 35', 'Show employees where age is 45', 'Show employees where age is less than 30', 'Show employees where department is not sales', 'Show employees where department is not engineering', 'Show employees where department is marketing', 'Show employees where id is 1', 'Show employees where id is less than 2', 'Show employees where id is greater than 3', 'Show employees where name is not eve', 'Show employees where name is david', 'Show employees where name is alice', 'Show employees where age is 35', 'Show employees where age is 45', 'Show employees where age is less than 30', 'Show employees where department is not sales', 'Show employees where department is not engineering', 'Show employees where department is marketing'], model='azure/text-embedding-ada-002', api_base='https://ist-apim-aoai.azure-api.net/load-balancing/text-embedding-ada-002', api_version='2024-10-21', api_key='4e86557a89d24a95a61d41e02cf62d1d')
# 23:12:39 - LiteLLM:DEBUG: utils.py:331 -
#
# 23:12:39 - LiteLLM:DEBUG: litellm_logging.py:427 - self.optional_params: {}
# 23:12:39 - LiteLLM:DEBUG: utils.py:331 - SYNC kwargs[caching]: False; litellm.cache: None; kwargs.get('cache')['no-cache']: False
# 23:12:39 - LiteLLM:DEBUG: litellm_logging.py:427 - self.optional_params: {}
# 23:12:39 - LiteLLM:DEBUG: litellm_logging.py:870 - {'litellm_trace_id': None, 'litellm_call_id': 'dda02d16-1828-4578-89da-593945cc74d8', 'input': ['Show employees where id is 1', 'Show employees where id is less than 2', 'Show employees where id is greater than 3', 'Show employees where name is not eve', 'Show employees where name is david', 'Show employees where name is alice', 'Show employees where age is 35', 'Show employees where age is 45', 'Show employees where age is less than 30', 'Show employees where department is not sales', 'Show employees where department is not engineering', 'Show employees where department is marketing', 'Show employees where id is 1', 'Show employees where id is less than 2', 'Show employees where id is greater than 3', 'Show employees where name is not eve', 'Show employees where name is david', 'Show employees where name is alice', 'Show employees where age is 35', 'Show employees where age is 45', 'Show employees where age is less than 30', 'Show employees where department is not sales', 'Show employees where department is not engineering', 'Show employees where department is marketing'], 'litellm_params': {'acompletion': None, 'api_key': None, 'force_timeout': 600, 'logger_fn': None, 'verbose': False, 'custom_llm_provider': None, 'api_base': '', 'litellm_call_id': None, 'model_alias_map': None, 'completion_call_id': None, 'aembedding': None, 'metadata': None, 'model_info': None, 'proxy_server_request': None, 'preset_cache_key': None, 'no-log': None, 'stream_response': {}, 'input_cost_per_token': None, 'input_cost_per_second': None, 'output_cost_per_token': None, 'output_cost_per_second': None, 'cooldown_time': None, 'text_completion': None, 'azure_ad_token_provider': None, 'user_continue_message': None, 'base_model': None, 'litellm_trace_id': None, 'litellm_session_id': None, 'hf_model_name': None, 'custom_prompt_dict': None, 'litellm_metadata': None, 'disable_add_transform_inline_image_block': None, 'drop_params': None, 'prompt_id': None, 'prompt_variables': None, 'async_call': None, 'ssl_verify': None, 'merge_reasoning_content_in_choices': None, 'api_version': None, 'azure_ad_token': None, 'tenant_id': None, 'client_id': None, 'client_secret': None, 'azure_username': None, 'azure_password': None, 'max_retries': None, 'timeout': None, 'bucket_name': None, 'vertex_credentials': None, 'vertex_project': None}, 'applied_guardrails': [], 'model': 'text-embedding-ada-002', 'messages': [{'role': 'user', 'content': 'Show employees where id is 1'}, {'role': 'user', 'content': 'Show employees where id is less than 2'}, {'role': 'user', 'content': 'Show employees where id is greater than 3'}, {'role': 'user', 'content': 'Show employees where name is not eve'}, {'role': 'user', 'content': 'Show employees where name is david'}, {'role': 'user', 'content': 'Show employees where name is alice'}, {'role': 'user', 'content': 'Show employees where age is 35'}, {'role': 'user', 'content': 'Show employees where age is 45'}, {'role': 'user', 'content': 'Show employees where age is less than 30'}, {'role': 'user', 'content': 'Show employees where department is not sales'}, {'role': 'user', 'content': 'Show employees where department is not engineering'}, {'role': 'user', 'content': 'Show employees where department is marketing'}, {'role': 'user', 'content': 'Show employees where id is 1'}, {'role': 'user', 'content': 'Show employees where id is less than 2'}, {'role': 'user', 'content': 'Show employees where id is greater than 3'}, {'role': 'user', 'content': 'Show employees where name is not eve'}, {'role': 'user', 'content': 'Show employees where name is david'}, {'role': 'user', 'content': 'Show employees where name is alice'}, {'role': 'user', 'content': 'Show employees where age is 35'}, {'role': 'user', 'content': 'Show employees where age is 45'}, {'role': 'user', 'content': 'Show employees where age is less than 30'}, {'role': 'user', 'content': 'Show employees where department is not sales'}, {'role':  ...
#
# 23:12:40 - LiteLLM:DEBUG: utils.py:331 - RAW RESPONSE:
# CreateEmbeddingResponse(data=[Embedding(embedding=[-0.02016945742070675, -0.0086522800847888, -0.02977190539240837, -0.004891201388090849, -0.01071817334741354, 0.013007212430238724, -0.02778519131243229, 0.004347734618932009, 0.002567970659583807, -0.019161704927682877, 0.014266904443502426, 0.00785327609628439, -0.004898399580270052, 0.0021720677614212036, -0.022069791331887245, 0.004833615384995937, 0.00950167141854763, -0.015418621711432934, 0.006971491500735283, -0.00950167141854763, -0.035271357744932175, 0.013590269722044468, 0.00852271169424057, 0.007975645363330841, -0.019320065155625343, -0.0027731205336749554, 0.009580852463841438, -0.01618163473904133, 0.0022134575992822647, -0.011574763804674149, 0.015576982870697975, -0.027756398543715477, -0.01592249795794487, -0.02905208058655262, -0.03504101186990738, -0.013410313986241817, -0.00290088914334774, 0.010559812188148499, 0.039043232798576355, -0.004239761270582676, 0.02310633845627308, -0.017462920397520065, -0.006482011638581753, -0.028260275721549988, -0.006957095116376877, 0.03521377220749855, -0.04065563902258873, -0.00018591694242786616, 0.0036333096213638783, 0.02086048759520054, 0.0021630700211972, 0.04330458864569664, -0.041548218578100204, -0.015130692161619663, 0.00039882728015072644, -0.0024222065694630146, 0.03337102383375168, 0.02931121736764908, -0.0040346113964915276, -0.0060537164099514484, 0.003098840592429042, -0.019593598321080208, -0.03478187695145607, -0.002391614019870758, -0.015260260552167892, -0.0008017035434022546, 0.010466235689818859, 0.004991977009922266, 0.006042919121682644, -0.0051935273222625256, 0.04039650037884712, 0.007014681119471788, -0.003703492460772395, 0.005373483523726463, 0.02785717323422432, -0.008573099039494991, -0.007810086011886597, 0.0029584751464426517, 0.04172097519040108, -0.006546795833855867, 0.018110761418938637, -0.027612434700131416, -0.015476208180189133, 0.009983954019844532, 0.015245864167809486, 0.01737654209136963, -0.008054826408624649, 0.03774755075573921, -0.01976635679602623, 0.005301501136273146, 0.02012626826763153, 0.0027173340786248446, 0.0022638451773673296, -0.019895924255251884, 0.0049415891990065575, 0.012035450898110867, -0.024070901796221733, 0.027367694303393364, 0.005053161643445492, -0.04805542528629303, -0.0023412262089550495, -0.014410869218409061, -0.018413087353110313, 0.0022440501488745213, -0.026316750794649124, -0.01149558275938034, -0.02002549357712269, -0.010883732698857784, 0.01988152787089348, 0.003262600628659129, -0.03351498767733574, 0.01795240119099617, 0.021781861782073975, -0.020802902057766914, -0.016512753441929817, -0.019420841708779335, -0.009839989244937897, 0.00013901593047194183, -0.012726481072604656, -0.010264684446156025, 0.03578963130712509, 0.037661172449588776, 0.003167223883792758, -0.03043414279818535, 0.03840978816151619, 0.013467899523675442, -0.034983426332473755, -0.028461825102567673, 0.008047628216445446, -0.003111437661573291, 0.06651170551776886, 0.024646760895848274, 0.03017500601708889, 0.014115741476416588, -0.03455153480172157, -0.01661352813243866, -0.00029917669598944485, 0.02962793968617916, -0.012834454886615276, -0.027482865378260612, 0.025179430842399597, 0.0034641511738300323, 0.008760252967476845, 0.01845627836883068, 0.02176746539771557, 0.018902568146586418, 0.0015143288765102625, 0.0017257771687582135, -0.03463791310787201, -0.028044328093528748, 0.0075365533120930195, 0.006993086542934179, -0.016483960673213005, 0.0027965146582573652, 0.011617952957749367, 0.012856049463152885, -0.0033021909184753895, -0.00456008268520236, 0.01432448998093605, -0.03953271359205246, -0.002762323012575507, 0.01991032063961029, -0.00799723993986845, -0.023221509531140327, 0.031211551278829575, 0.037517208606004715, 0.03397567570209503, -0.011106878519058228, -0.01333113294094801, 0.00894020963460207, 0.016728701069951057, 0.0030808451119810343, -0.022717634215950966, 0.017203783616423607, -0.006323650479316711, -0.00026476013590581715, -0.02281840890 ...
#
#
# 23:12:40 - LiteLLM:INFO: utils.py:1184 - Wrapper: Completed Call, calling success_handler
# 23:12:40 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: azure/text-embedding-ada-002
# 23:12:40 - LiteLLM:DEBUG: litellm_logging.py:1315 - Logging Details LiteLLM-Success Call: Cache_hit=None
# 23:12:40 - LiteLLM:DEBUG: utils.py:4154 - checking potential_model_names in litellm.model_cost: {'split_model': 'text-embedding-ada-002', 'combined_model_name': 'azure/text-embedding-ada-002', 'stripped_model_name': 'text-embedding-ada-002', 'combined_stripped_model_name': 'azure/text-embedding-ada-002', 'custom_llm_provider': 'azure'}
# 23:12:40 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: azure/text-embedding-ada-002
# 23:12:40 - LiteLLM:DEBUG: utils.py:4450 - model_info: {'key': 'azure/text-embedding-ada-002', 'max_tokens': 8191, 'max_input_tokens': 8191, 'max_output_tokens': None, 'input_cost_per_token': 1e-07, 'cache_creation_input_token_cost': None, 'cache_read_input_token_cost': None, 'input_cost_per_character': None, 'input_cost_per_token_above_128k_tokens': None, 'input_cost_per_token_above_200k_tokens': None, 'input_cost_per_query': None, 'input_cost_per_second': None, 'input_cost_per_audio_token': None, 'input_cost_per_token_batches': None, 'output_cost_per_token_batches': None, 'output_cost_per_token': 0.0, 'output_cost_per_audio_token': None, 'output_cost_per_character': None, 'output_cost_per_reasoning_token': None, 'output_cost_per_token_above_128k_tokens': None, 'output_cost_per_character_above_128k_tokens': None, 'output_cost_per_token_above_200k_tokens': None, 'output_cost_per_second': None, 'output_cost_per_image': None, 'output_vector_size': None, 'litellm_provider': 'azure', 'mode': 'embedding', 'supports_system_messages': None, 'supports_response_schema': None, 'supports_vision': False, 'supports_function_calling': False, 'supports_tool_choice': False, 'supports_assistant_prefill': False, 'supports_prompt_caching': False, 'supports_audio_input': False, 'supports_audio_output': False, 'supports_pdf_input': False, 'supports_embedding_image_input': False, 'supports_native_streaming': None, 'supports_web_search': False, 'supports_reasoning': False, 'search_context_cost_per_query': None, 'tpm': None, 'rpm': None}
# 23:12:40 - LiteLLM:DEBUG: utils.py:4154 - checking potential_model_names in litellm.model_cost: {'split_model': 'text-embedding-ada-002', 'combined_model_name': 'azure/text-embedding-ada-002', 'stripped_model_name': 'text-embedding-ada-002', 'combined_stripped_model_name': 'azure/text-embedding-ada-002', 'custom_llm_provider': 'azure'}
# 23:12:40 - LiteLLM:DEBUG: litellm_logging.py:1093 - response_cost: 1.74e-05
# 23:12:40 - LiteLLM:DEBUG: utils.py:4450 - model_info: {'key': 'azure/text-embedding-ada-002', 'max_tokens': 8191, 'max_input_tokens': 8191, 'max_output_tokens': None, 'input_cost_per_token': 1e-07, 'cache_creation_input_token_cost': None, 'cache_read_input_token_cost': None, 'input_cost_per_character': None, 'input_cost_per_token_above_128k_tokens': None, 'input_cost_per_token_above_200k_tokens': None, 'input_cost_per_query': None, 'input_cost_per_second': None, 'input_cost_per_audio_token': None, 'input_cost_per_token_batches': None, 'output_cost_per_token_batches': None, 'output_cost_per_token': 0.0, 'output_cost_per_audio_token': None, 'output_cost_per_character': None, 'output_cost_per_reasoning_token': None, 'output_cost_per_token_above_128k_tokens': None, 'output_cost_per_character_above_128k_tokens': None, 'output_cost_per_token_above_200k_tokens': None, 'output_cost_per_second': None, 'output_cost_per_image': None, 'output_vector_size': None, 'litellm_provider': 'azure', 'mode': 'embedding', 'supports_system_messages': None, 'supports_response_schema': None, 'supports_vision': False, 'supports_function_calling': False, 'supports_tool_choice': False, 'supports_assistant_prefill': False, 'supports_prompt_caching': False, 'supports_audio_input': False, 'supports_audio_output': False, 'supports_pdf_input': False, 'supports_embedding_image_input': False, 'supports_native_streaming': None, 'supports_web_search': False, 'supports_reasoning': False, 'search_context_cost_per_query': None, 'tpm': None, 'rpm': None}
# 23:12:40 - LiteLLM:DEBUG: utils.py:331 -
#
# 23:12:40 - LiteLLM:DEBUG: litellm_logging.py:1093 - response_cost: 1.74e-05
# 23:12:40 - LiteLLM:DEBUG: utils.py:331 - Request to litellm:
# 23:12:40 - LiteLLM:DEBUG: utils.py:4154 - checking potential_model_names in litellm.model_cost: {'split_model': 'text-embedding-ada-002', 'combined_model_name': 'azure/text-embedding-ada-002', 'stripped_model_name': 'text-embedding-ada-002', 'combined_stripped_model_name': 'azure/text-embedding-ada-002', 'custom_llm_provider': 'azure'}
# 23:12:40 - LiteLLM:DEBUG: utils.py:331 - litellm.embedding(input=['Who works in Engineering?'], model='azure/text-embedding-ada-002', api_base='https://ist-apim-aoai.azure-api.net/load-balancing/text-embedding-ada-002', api_version='2024-10-21', api_key='4e86557a89d24a95a61d41e02cf62d1d')
# 23:12:40 - LiteLLM:DEBUG: utils.py:4450 - model_info: {'key': 'azure/text-embedding-ada-002', 'max_tokens': 8191, 'max_input_tokens': 8191, 'max_output_tokens': None, 'input_cost_per_token': 1e-07, 'cache_creation_input_token_cost': None, 'cache_read_input_token_cost': None, 'input_cost_per_character': None, 'input_cost_per_token_above_128k_tokens': None, 'input_cost_per_token_above_200k_tokens': None, 'input_cost_per_query': None, 'input_cost_per_second': None, 'input_cost_per_audio_token': None, 'input_cost_per_token_batches': None, 'output_cost_per_token_batches': None, 'output_cost_per_token': 0.0, 'output_cost_per_audio_token': None, 'output_cost_per_character': None, 'output_cost_per_reasoning_token': None, 'output_cost_per_token_above_128k_tokens': None, 'output_cost_per_character_above_128k_tokens': None, 'output_cost_per_token_above_200k_tokens': None, 'output_cost_per_second': None, 'output_cost_per_image': None, 'output_vector_size': None, 'litellm_provider': 'azure', 'mode': 'embedding', 'supports_system_messages': None, 'supports_response_schema': None, 'supports_vision': False, 'supports_function_calling': False, 'supports_tool_choice': False, 'supports_assistant_prefill': False, 'supports_prompt_caching': False, 'supports_audio_input': False, 'supports_audio_output': False, 'supports_pdf_input': False, 'supports_embedding_image_input': False, 'supports_native_streaming': None, 'supports_web_search': False, 'supports_reasoning': False, 'search_context_cost_per_query': None, 'tpm': None, 'rpm': None}
# 23:12:40 - LiteLLM:DEBUG: utils.py:331 -
#
# 23:12:40 - LiteLLM:DEBUG: litellm_logging.py:427 - self.optional_params: {}
# 23:12:40 - LiteLLM:DEBUG: utils.py:331 - SYNC kwargs[caching]: False; litellm.cache: None; kwargs.get('cache')['no-cache']: False
# 23:12:40 - LiteLLM:DEBUG: litellm_logging.py:427 - self.optional_params: {}
# 23:12:40 - LiteLLM:DEBUG: litellm_logging.py:870 - {'litellm_trace_id': None, 'litellm_call_id': '97903767-46ef-41c7-9166-4e57bde92a2d', 'input': ['Who works in Engineering?'], 'litellm_params': {'acompletion': None, 'api_key': None, 'force_timeout': 600, 'logger_fn': None, 'verbose': False, 'custom_llm_provider': None, 'api_base': '', 'litellm_call_id': None, 'model_alias_map': None, 'completion_call_id': None, 'aembedding': None, 'metadata': None, 'model_info': None, 'proxy_server_request': None, 'preset_cache_key': None, 'no-log': None, 'stream_response': {}, 'input_cost_per_token': None, 'input_cost_per_second': None, 'output_cost_per_token': None, 'output_cost_per_second': None, 'cooldown_time': None, 'text_completion': None, 'azure_ad_token_provider': None, 'user_continue_message': None, 'base_model': None, 'litellm_trace_id': None, 'litellm_session_id': None, 'hf_model_name': None, 'custom_prompt_dict': None, 'litellm_metadata': None, 'disable_add_transform_inline_image_block': None, 'drop_params': None, 'prompt_id': None, 'prompt_variables': None, 'async_call': None, 'ssl_verify': None, 'merge_reasoning_content_in_choices': None, 'api_version': None, 'azure_ad_token': None, 'tenant_id': None, 'client_id': None, 'client_secret': None, 'azure_username': None, 'azure_password': None, 'max_retries': None, 'timeout': None, 'bucket_name': None, 'vertex_credentials': None, 'vertex_project': None}, 'applied_guardrails': [], 'model': 'text-embedding-ada-002', 'messages': [{'role': 'user', 'content': 'Who works in Engineering?'}], 'optional_params': {}, 'start_time': datetime.datetime(2025, 5, 9, 23, 12, 40, 671165), 'stream': False, 'user': None, 'call_type': 'embedding', 'completion_start_time': None, 'standard_callback_dynamic_params': {}, 'stream_options': None, 'custom_llm_provider': 'azure', 'api_key': '4e86557a89d24a95a61d41e02cf62d1d', 'additional_args': {'complete_input_dict': {'model': 'text-embedding-ada-002', 'input': ['Who works in Engineering?']}, 'headers': {'api_key': '4e86557a89d24a95a61d41e02cf62d1d', 'azure_ad_token': None}}, 'log_event_type': 'pre_api_call'}
#
# 23:12:40 - LiteLLM:DEBUG: utils.py:331 - RAW RESPONSE:
# CreateEmbeddingResponse(data=[Embedding(embedding=[0.01560231763869524, -0.011051085777580738, -0.0038104890845716, -0.03280624374747276, -0.018231621012091637, 0.01196533627808094, -0.004998347256332636, 0.018231621012091637, -0.0029246003832668066, -0.02032705768942833, 0.0222623310983181, 0.005385402124375105, -0.001975314924493432, 0.007173862773925066, 0.00208542519249022, -0.007380736991763115, 0.023516923189163208, 0.013353395275771618, 0.001697536208666861, -0.005969321355223656, -0.009496192447841167, 0.011751788668334484, 0.016376428306102753, -0.0067367576994001865, -0.0046680159866809845, -0.005308658350259066, 0.025972720235586166, -0.01765771210193634, 0.012532571330666542, -0.019286012277007103, 0.02805480919778347, -0.006022708024829626, -0.024477887898683548, -0.015081795863807201, -0.03331341594457626, -0.00585921062156558, -0.0003766278096009046, 0.007947972975671291, 0.030056817457079887, 0.021821890026330948, 0.04134814441204071, 0.01625630632042885, 0.007233923301100731, -0.019659720361232758, -0.017844567075371742, 0.031338103115558624, 0.004818166606128216, -0.0011036070063710213, -0.02493167668581009, 0.021901970729231834, 0.016977030783891678, 0.01316654123365879, -0.009142504073679447, -0.029683109372854233, -0.02445119433104992, 0.012012049555778503, -0.02248922549188137, 0.02322329580783844, -0.014107485301792622, -0.0009234262979589403, 0.01437441911548376, 0.002904580207541585, -0.03309987112879753, 0.004661342594772577, -0.0046012825332582, -0.012472511269152164, -0.005365381948649883, 0.011491527780890465, -0.0053320154547691345, -0.0074007571674883366, 0.022862933576107025, -0.009009037166833878, -0.004404418170452118, 0.009389419108629227, 0.0075742644257843494, -0.011157859116792679, -0.004404418170452118, -0.01763101853430271, -0.0011753457365557551, -0.0050217038951814175, 0.006066084839403629, -0.021194593980908394, -0.008982343599200249, 0.012432470917701721, -0.0040373834781348705, -0.005975994747132063, 0.00611613504588604, -0.0034801578149199486, -0.010964332148432732, -0.01963302679359913, -0.017817873507738113, 0.02541215904057026, 0.026653403416275978, 0.0022238974925130606, 0.01859198324382305, 9.658126145950519e-06, -0.011184552684426308, 0.003183193039149046, 0.001493164454586804, -0.028588678687810898, -0.004824839998036623, 0.0073273503221571445, 0.0044277748093008995, 0.011344713158905506, -0.018538596108555794, 0.00010750367073342204, 0.004414428025484085, -0.0200467761605978, 0.03021697886288166, -0.030083511024713516, -0.01665670797228813, 0.03261938691139221, 0.00011647100473055616, -0.025545625016093254, 0.012559264898300171, -0.049249403178691864, 0.013333374634385109, -0.018285008147358894, -0.00020531011978164315, -0.0007290646899491549, 0.03382059186697006, 0.0013955666217952967, 0.022595999762415886, -0.01645650714635849, 0.030617380514740944, 0.008915609680116177, -0.020887618884444237, -0.006229582242667675, -0.0003795473894570023, -0.012078783474862576, 0.006046065129339695, 0.0023757165763527155, 0.006579933688044548, 0.018979039043188095, 0.0024591335095465183, -0.0126793859526515, 0.00056556734489277, 0.016563281416893005, -0.026760177686810493, -0.014748127199709415, 0.004774789791554213, -0.0012921295128762722, 0.0030897660180926323, -0.00230397772975266, -0.017243964597582817, 0.003251595189794898, 0.02874883823096752, -0.005869220942258835, 0.004467815160751343, -0.00904907751828432, -0.010497196577489376, 0.013393435627222061, 0.01307311374694109, -0.0010493859881535172, -0.0038772227708250284, 0.015428810380399227, -0.011878582648932934, 0.010704071260988712, -0.008288314566016197, -0.013219928368926048, -0.01933939941227436, -0.007587611209601164, 0.02034040354192257, -0.023116521537303925, 0.0033383488189429045, 0.02342349663376808, 0.012852893210947514, 0.02343684248626232, 0.014414459466934204, 0.0024574650451540947, -0.016549935564398766, 0.020941006019711494, -0.027921341359615326, 0.003520197933539748, 0.013093134388327599, 0.007887912914156914, 0 ...
#
#
# 23:12:40 - LiteLLM:INFO: utils.py:1184 - Wrapper: Completed Call, calling success_handler
# 23:12:40 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: azure/text-embedding-ada-002
# 23:12:40 - LiteLLM:DEBUG: litellm_logging.py:1315 - Logging Details LiteLLM-Success Call: Cache_hit=None
# 23:12:40 - LiteLLM:DEBUG: utils.py:4154 - checking potential_model_names in litellm.model_cost: {'split_model': 'text-embedding-ada-002', 'combined_model_name': 'azure/text-embedding-ada-002', 'stripped_model_name': 'text-embedding-ada-002', 'combined_stripped_model_name': 'azure/text-embedding-ada-002', 'custom_llm_provider': 'azure'}
# 23:12:40 - LiteLLM:INFO: cost_calculator.py:655 - selected model name for cost calculation: azure/text-embedding-ada-002
# 23:12:40 - LiteLLM:DEBUG: utils.py:4450 - model_info: {'key': 'azure/text-embedding-ada-002', 'max_tokens': 8191, 'max_input_tokens': 8191, 'max_output_tokens': None, 'input_cost_per_token': 1e-07, 'cache_creation_input_token_cost': None, 'cache_read_input_token_cost': None, 'input_cost_per_character': None, 'input_cost_per_token_above_128k_tokens': None, 'input_cost_per_token_above_200k_tokens': None, 'input_cost_per_query': None, 'input_cost_per_second': None, 'input_cost_per_audio_token': None, 'input_cost_per_token_batches': None, 'output_cost_per_token_batches': None, 'output_cost_per_token': 0.0, 'output_cost_per_audio_token': None, 'output_cost_per_character': None, 'output_cost_per_reasoning_token': None, 'output_cost_per_token_above_128k_tokens': None, 'output_cost_per_character_above_128k_tokens': None, 'output_cost_per_token_above_200k_tokens': None, 'output_cost_per_second': None, 'output_cost_per_image': None, 'output_vector_size': None, 'litellm_provider': 'azure', 'mode': 'embedding', 'supports_system_messages': None, 'supports_response_schema': None, 'supports_vision': False, 'supports_function_calling': False, 'supports_tool_choice': False, 'supports_assistant_prefill': False, 'supports_prompt_caching': False, 'supports_audio_input': False, 'supports_audio_output': False, 'supports_pdf_input': False, 'supports_embedding_image_input': False, 'supports_native_streaming': None, 'supports_web_search': False, 'supports_reasoning': False, 'search_context_cost_per_query': None, 'tpm': None, 'rpm': None}
# 23:12:40 - LiteLLM:DEBUG: utils.py:4154 - checking potential_model_names in litellm.model_cost: {'split_model': 'text-embedding-ada-002', 'combined_model_name': 'azure/text-embedding-ada-002', 'stripped_model_name': 'text-embedding-ada-002', 'combined_stripped_model_name': 'azure/text-embedding-ada-002', 'custom_llm_provider': 'azure'}
# 23:12:41 - LiteLLM:DEBUG: utils.py:4450 - model_info: {'key': 'azure/text-embedding-ada-002', 'max_tokens': 8191, 'max_input_tokens': 8191, 'max_output_tokens': None, 'input_cost_per_token': 1e-07, 'cache_creation_input_token_cost': None, 'cache_read_input_token_cost': None, 'input_cost_per_character': None, 'input_cost_per_token_above_128k_tokens': None, 'input_cost_per_token_above_200k_tokens': None, 'input_cost_per_query': None, 'input_cost_per_second': None, 'input_cost_per_audio_token': None, 'input_cost_per_token_batches': None, 'output_cost_per_token_batches': None, 'output_cost_per_token': 0.0, 'output_cost_per_audio_token': None, 'output_cost_per_character': None, 'output_cost_per_reasoning_token': None, 'output_cost_per_token_above_128k_tokens': None, 'output_cost_per_character_above_128k_tokens': None, 'output_cost_per_token_above_200k_tokens': None, 'output_cost_per_second': None, 'output_cost_per_image': None, 'output_vector_size': None, 'litellm_provider': 'azure', 'mode': 'embedding', 'supports_system_messages': None, 'supports_response_schema': None, 'supports_vision': False, 'supports_function_calling': False, 'supports_tool_choice': False, 'supports_assistant_prefill': False, 'supports_prompt_caching': False, 'supports_audio_input': False, 'supports_audio_output': False, 'supports_pdf_input': False, 'supports_embedding_image_input': False, 'supports_native_streaming': None, 'supports_web_search': False, 'supports_reasoning': False, 'search_context_cost_per_query': None, 'tpm': None, 'rpm': None}
# 23:12:41 - LiteLLM:DEBUG: litellm_logging.py:1093 - response_cost: 5e-07
# 23:12:41 - LiteLLM:DEBUG: litellm_logging.py:1093 - response_cost: 5e-07
# 23:12:41 - LiteLLM:DEBUG: utils.py:331 -
#
# 23:12:41 - LiteLLM:DEBUG: utils.py:4154 - checking potential_model_names in litellm.model_cost: {'split_model': 'text-embedding-ada-002', 'combined_model_name': 'azure/text-embedding-ada-002', 'stripped_model_name': 'text-embedding-ada-002', 'combined_stripped_model_name': 'azure/text-embedding-ada-002', 'custom_llm_provider': 'azure'}
# 23:12:41 - LiteLLM:DEBUG: utils.py:331 - Request to litellm:
# 23:12:41 - LiteLLM:DEBUG: utils.py:4450 - model_info: {'key': 'azure/text-embedding-ada-002', 'max_tokens': 8191, 'max_input_tokens': 8191, 'max_output_tokens': None, 'input_cost_per_token': 1e-07, 'cache_creation_input_token_cost': None, 'cache_read_input_token_cost': None, 'input_cost_per_character': None, 'input_cost_per_token_above_128k_tokens': None, 'input_cost_per_token_above_200k_tokens': None, 'input_cost_per_query': None, 'input_cost_per_second': None, 'input_cost_per_audio_token': None, 'input_cost_per_token_batches': None, 'output_cost_per_token_batches': None, 'output_cost_per_token': 0.0, 'output_cost_per_audio_token': None, 'output_cost_per_character': None, 'output_cost_per_reasoning_token': None, 'output_cost_per_token_above_128k_tokens': None, 'output_cost_per_character_above_128k_tokens': None, 'output_cost_per_token_above_200k_tokens': None, 'output_cost_per_second': None, 'output_cost_per_image': None, 'output_vector_size': None, 'litellm_provider': 'azure', 'mode': 'embedding', 'supports_system_messages': None, 'supports_response_schema': None, 'supports_vision': False, 'supports_function_calling': False, 'supports_tool_choice': False, 'supports_assistant_prefill': False, 'supports_prompt_caching': False, 'supports_audio_input': False, 'supports_audio_output': False, 'supports_pdf_input': False, 'supports_embedding_image_input': False, 'supports_native_streaming': None, 'supports_web_search': False, 'supports_reasoning': False, 'search_context_cost_per_query': None, 'tpm': None, 'rpm': None}
# 23:12:41 - LiteLLM:DEBUG: utils.py:331 - litellm.embedding(input=['Who works in Engineering?'], model='azure/text-embedding-ada-002', api_base='https://ist-apim-aoai.azure-api.net/load-balancing/text-embedding-ada-002', api_version='2024-10-21', api_key='4e86557a89d24a95a61d41e02cf62d1d')
# 23:12:41 - LiteLLM:DEBUG: utils.py:331 -
#
# 23:12:41 - LiteLLM:DEBUG: litellm_logging.py:427 - self.optional_params: {}
# 23:12:41 - LiteLLM:DEBUG: utils.py:331 - SYNC kwargs[caching]: False; litellm.cache: None; kwargs.get('cache')['no-cache']: False
# 23:12:41 - LiteLLM:DEBUG: litellm_logging.py:427 - self.optional_params: {}
# 23:12:41 - LiteLLM:DEBUG: litellm_logging.py:870 - {'litellm_trace_id': None, 'litellm_call_id': 'a31b5b2f-b07c-47b0-9dfa-283e7201e38d', 'input': ['Who works in Engineering?'], 'litellm_params': {'acompletion': None, 'api_key': None, 'force_timeout': 600, 'logger_fn': None, 'verbose': False, 'custom_llm_provider': None, 'api_base': '', 'litellm_call_id': None, 'model_alias_map': None, 'completion_call_id': None, 'aembedding': None, 'metadata': None, 'model_info': None, 'proxy_server_request': None, 'preset_cache_key': None, 'no-log': None, 'stream_response': {}, 'input_cost_per_token': None, 'input_cost_per_second': None, 'output_cost_per_token': None, 'output_cost_per_second': None, 'cooldown_time': None, 'text_completion': None, 'azure_ad_token_provider': None, 'user_continue_message': None, 'base_model': None, 'litellm_trace_id': None, 'litellm_session_id': None, 'hf_model_name': None, 'custom_prompt_dict': None, 'litellm_metadata': None, 'disable_add_transform_inline_image_block': None, 'drop_params': None, 'prompt_id': None, 'prompt_variables': None, 'async_call': None, 'ssl_verify': None, 'merge_reasoning_content_in_choices': None, 'api_version': None, 'azure_ad_token': None, 'tenant_id': None, 'client_id': None, 'client_secret': None, 'azure_username': None, 'azure_password': None, 'max_retries': None, 'timeout': None, 'bucket_name': None, 'vertex_credentials': None, 'vertex_project': None}, 'applied_guardrails': [], 'model': 'text-embedding-ada-002', 'messages': [{'role': 'user', 'content': 'Who works in Engineering?'}], 'optional_params': {}, 'start_time': datetime.datetime(2025, 5, 9, 23, 12, 41, 11770), 'stream': False, 'user': None, 'call_type': 'embedding', 'completion_start_time': None, 'standard_callback_dynamic_params': {}, 'stream_options': None, 'custom_llm_provider': 'azure', 'api_key': '4e86557a89d24a95a61d41e02cf62d1d', 'additional_args': {'complete_input_dict': {'model': 'text-embedding-ada-002', 'input': ['Who works in Engineering?']}, 'headers': {'api_key': '4e86557a89d24a95a61d41e02cf62d1d', 'azure_ad_token': None}}, 'log_event_type': 'pre_api_call'}
#
# 23:12:41 - LiteLLM:DEBUG: utils.py:331 - RAW RESPONSE:
# ...
#
#
# 23:12:42 - LiteLLM:DEBUG: main.py:5742 - openai.py: Received openai error - Error code: 404 - {'statusCode': 404, 'message': 'Resource not found'}
# 23:12:42 - LiteLLM:DEBUG: utils.py:331 - RAW RESPONSE:
# Error code: 404 - {'statusCode': 404, 'message': 'Resource not found'}
#
#
# 23:12:42 - LiteLLM:DEBUG: exception_mapping_utils.py:2253 - Logging Details: logger_fn - None | callable(logger_fn) - False
# 23:12:42 - LiteLLM:DEBUG: litellm_logging.py:2128 - Logging Details LiteLLM-Failure Call: []
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# File c:\Users\jac10179\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\Lib\site-packages\litellm\llms\openai\openai.py:724, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, api_version, dynamic_params, azure_ad_token, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     723             else:
# --> 724                 raise e
#     725 except OpenAIError as e:
#
# File c:\Users\jac10179\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\Lib\site-packages\litellm\llms\openai\openai.py:652, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, api_version, dynamic_params, azure_ad_token, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     638 logging_obj.pre_call(
#     639     input=messages,
#     640     api_key=openai_client.api_key,
#    (...)
#     646     },
#     647 )
#     649 (
#     650     headers,
#     651     response,
# --> 652 ) = self.make_sync_openai_chat_completion_request(
#     653     openai_client=openai_client,
#     654     data=data,
#     655     timeout=timeout,
#     656     logging_obj=logging_obj,
#     657 )
#     659 logging_obj.model_call_details["response_headers"] = headers
#
# File c:\Users\jac10179\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\Lib\site-packages\litellm\litellm_core_utils\logging_utils.py:149, in track_llm_api_timing.<locals>.decorator.<locals>.sync_wrapper(*args, **kwargs)
#     148 try:
# --> 149     result = func(*args, **kwargs)
#     150     return result
#
# File c:\Users\jac10179\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\Lib\site-packages\litellm\llms\openai\openai.py:471, in OpenAIChatCompletion.make_sync_openai_chat_completion_request(self, openai_client, data, timeout, logging_obj)
#     470 else:
# --> 471     raise e
#
# File c:\Users\jac10179\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\Lib\site-packages\litellm\llms\openai\openai.py:453, in OpenAIChatCompletion.make_sync_openai_chat_completion_request(self, openai_client, data, timeout, logging_obj)
#     452 try:
# --> 453     raw_response = openai_client.chat.completions.with_raw_response.create(
#     454         **data, timeout=timeout
#     455     )
#     457     if hasattr(raw_response, "headers"):
#
# File c:\Users\jac10179\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\Lib\site-packages\openai\_legacy_response.py:364, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     362 kwargs["extra_headers"] = extra_headers
# --> 364 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File c:\Users\jac10179\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\Lib\site-packages\openai\_utils\_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File c:\Users\jac10179\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\Lib\site-packages\openai\resources\chat\completions\completions.py:929, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     928 validate_response_format(response_format)
# --> 929 return self._post(
#     930     "/chat/completions",
#     931     body=maybe_transform(
#     932         {
#     933             "messages": messages,
#     934             "model": model,
#     935             "audio": audio,
#     936             "frequency_penalty": frequency_penalty,
#     937             "function_call": function_call,
#     938             "functions": functions,
#     939             "logit_bias": logit_bias,
#     940             "logprobs": logprobs,
#     941             "max_completion_tokens": max_completion_tokens,
#     942             "max_tokens": max_tokens,
#     943             "metadata": metadata,
#     944             "modalities": modalities,
#     945             "n": n,
#     946             "parallel_tool_calls": parallel_tool_calls,
#     947             "prediction": prediction,
#     948             "presence_penalty": presence_penalty,
#     949             "reasoning_effort": reasoning_effort,
#     950             "response_format": response_format,
#     951             "seed": seed,
#     952             "service_tier": service_tier,
#     953             "stop": stop,
#     954             "store": store,
#     955             "stream": stream,
#     956             "stream_options": stream_options,
#     957             "temperature": temperature,
#     958             "tool_choice": tool_choice,
#     959             "tools": tools,
#     960             "top_logprobs": top_logprobs,
#     961             "top_p": top_p,
#     962             "user": user,
#     963             "web_search_options": web_search_options,
#     964         },
#     965         completion_create_params.CompletionCreateParamsStreaming
#     966         if stream
#     967         else completion_create_params.CompletionCreateParamsNonStreaming,
#     968     ),
#     969     options=make_request_options(
#     970         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     971     ),
#     972     cast_to=ChatCompletion,
#     973     stream=stream or False,
#     974     stream_cls=Stream[ChatCompletionChunk],
#     975 )
#
# File c:\Users\jac10179\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\Lib\site-packages\openai\_base_client.py:1276, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1273 opts = FinalRequestOptions.construct(
#    1274     method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1275 )
# -> 1276 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\jac10179\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\Lib\site-packages\openai\_base_client.py:949, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     947     retries_taken = 0
# --> 949 return self._request(
#     950     cast_to=cast_to,
#     951     options=options,
#     952     stream=stream,
#     953     stream_cls=stream_cls,
#     954     retries_taken=retries_taken,
#     955 )
#
# File c:\Users\jac10179\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\Lib\site-packages\openai\_base_client.py:1057, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1056     log.debug("Re-raising status error")
# -> 1057     raise self._make_status_error_from_response(err.response) from None
#    1059 return self._process_response(
#    1060     cast_to=cast_to,
#    1061     options=options,
#    (...)
#    1065     retries_taken=retries_taken,
#    1066 )
#
# NotFoundError: Error code: 404 - {'statusCode': 404, 'message': 'Resource not found'}
#
# During handling of the above exception, another exception occurred:
#
# OpenAIError                               Traceback (most recent call last)
# File c:\Users\jac10179\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\Lib\site-packages\litellm\main.py:1831, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    1825     logging.post_call(
#    1826         input=messages,
#    1827         api_key=api_key,
#    1828         original_response=str(e),
#    1829         additional_args={"headers": headers},
#    1830     )
# -> 1831     raise e
#    1833 if optional_params.get("stream", False):
#    1834     ## LOGGING
#
# File c:\Users\jac10179\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\Lib\site-packages\litellm\main.py:1804, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    1803 try:
# -> 1804     response = openai_chat_completions.completion(
#    1805         model=model,
#    1806         messages=messages,
#    1807         headers=headers,
#    1808         model_response=model_response,
#    1809         print_verbose=print_verbose,
#    1810         api_key=api_key,
#    1811         api_base=api_base,
#    1812         acompletion=acompletion,
#    1813         logging_obj=logging,
#    1814         optional_params=optional_params,
#    1815         litellm_params=litellm_params,
#    1816         logger_fn=logger_fn,
#    1817         timeout=timeout,  # type: ignore
#    1818         custom_prompt_dict=custom_prompt_dict,
#    1819         client=client,  # pass AsyncOpenAI, OpenAI client
#    1820         organization=organization,
#    1821         custom_llm_provider=custom_llm_provider,
#    1822     )
#    1823 except Exception as e:
#    1824     ## LOGGING - log the original exception returned
#
# File c:\Users\jac10179\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\Lib\site-packages\litellm\llms\openai\openai.py:735, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, litellm_params, logging_obj, model, messages, print_verbose, api_key, api_base, api_version, dynamic_params, azure_ad_token, acompletion, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider, drop_params)
#     734     error_headers = getattr(error_response, "headers", None)
# --> 735 raise OpenAIError(
#     736     status_code=status_code,
#     737     message=error_text,
#     738     headers=error_headers,
#     739     body=error_body,
#     740 )
#
# OpenAIError: Error code: 404 - {'statusCode': 404, 'message': 'Resource not found'}
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# Cell In[1], line 118
#     115 idris.load_question_sql(combined_result.question_sql)
#     117 # 9. Test query
# --> 118 sql = idris.generate_sql("Who works in Engineering?")
#     119 print(f"\nGenerated SQL: {sql}")
#     121 # 10. Test direct augmentation of an Idris instance
#
# File ~\Documents\Admin\Career\2025\AI\Fork\gait-main-JE\gait\idris\idris_base.py:305, in Idris.generate_sql(self, prompt, **kwargs)
#     300 # Add the user question.
#     301 messages.append(
#     302     self.idris_llm.create_message(role="user", content=prompt)
#     303 )
# --> 305 sql = self.idris_llm.generate_sql(messages, **kwargs)
#     306 if sql is not None:
#     307     sql = re.sub(r"\s*\n\s*", " ", sql).strip()
#
# File ~\Documents\Admin\Career\2025\AI\Fork\gait-main-JE\gait\idris\idris_litellm.py:67, in IdrisLiteLLM.generate_sql(self, messages, **kwargs)
#      55 def generate_sql(
#      56         self,
#      57         messages: List[Dict[str, str]],
#      58         **kwargs
#      59 ) -> Optional[str]:
#      60     params = {
#      61         "model": self.model_name,
#      62         "temperature": self.temperature,
#    (...)
#      65         **kwargs,
#      66     }
# ---> 67     response = completion(**params)
#      68     if self.logger.isEnabledFor(logging.DEBUG):
#      69         self.logger.debug(response)
#
# File c:\Users\jac10179\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\Lib\site-packages\litellm\utils.py:1254, in client.<locals>.wrapper(*args, **kwargs)
#    1250 if logging_obj:
#    1251     logging_obj.failure_handler(
#    1252         e, traceback_exception, start_time, end_time
#    1253     )  # DO NOT MAKE THREADED - router retry fallback relies on this!
# -> 1254 raise e
#
# File c:\Users\jac10179\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\Lib\site-packages\litellm\utils.py:1132, in client.<locals>.wrapper(*args, **kwargs)
#    1130         print_verbose(f"Error while checking max token limit: {str(e)}")
#    1131 # MODEL CALL
# -> 1132 result = original_function(*args, **kwargs)
#    1133 end_time = datetime.datetime.now()
#    1134 if "stream" in kwargs and kwargs["stream"] is True:
#
# File c:\Users\jac10179\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\Lib\site-packages\litellm\main.py:3216, in completion(model, messages, timeout, temperature, top_p, n, stream, stream_options, stop, max_completion_tokens, max_tokens, modalities, prediction, audio, presence_penalty, frequency_penalty, logit_bias, user, reasoning_effort, response_format, seed, tools, tool_choice, logprobs, top_logprobs, parallel_tool_calls, deployment_id, extra_headers, functions, function_call, base_url, api_version, api_key, model_list, thinking, **kwargs)
#    3213     return response
#    3214 except Exception as e:
#    3215     ## Map to OpenAI Exception
# -> 3216     raise exception_type(
#    3217         model=model,
#    3218         custom_llm_provider=custom_llm_provider,
#    3219         original_exception=e,
#    3220         completion_kwargs=args,
#    3221         extra_kwargs=kwargs,
#    3222     )
#
# File c:\Users\jac10179\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:2224, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#    2222 if exception_mapping_worked:
#    2223     setattr(e, "litellm_response_headers", litellm_response_headers)
# -> 2224     raise e
#    2225 else:
#    2226     for error_type in litellm.LITELLM_EXCEPTION_TYPES:
#
# File c:\Users\jac10179\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\Lib\site-packages\litellm\litellm_core_utils\exception_mapping_utils.py:405, in exception_type(model, original_exception, custom_llm_provider, completion_kwargs, extra_kwargs)
#     403 elif original_exception.status_code == 404:
#     404     exception_mapping_worked = True
# --> 405     raise NotFoundError(
#     406         message=f"NotFoundError: {exception_provider} - {message}",
#     407         model=model,
#     408         llm_provider=custom_llm_provider,
#     409         response=getattr(original_exception, "response", None),
#     410         litellm_debug_info=extra_information,
#     411     )
#     412 elif original_exception.status_code == 408:
#     413     exception_mapping_worked = True
#
# NotFoundError: litellm.NotFoundError: NotFoundError: OpenAIException - Resource not found
